# %% [markdown]
# ### Dependências

# %%
#provalvemente sua máquina não estará instalado as seguintes dependências, rode essa célula para instalá-las 😄

#!pip install pandasql
#!pip install SQLAlchemy==1.4.46

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import pandasql as ps

# %% [markdown]
# ## Importando dataset

# %%
df = pd.read_csv("https://raw.githubusercontent.com/gustavo-candidoo/data-science/main/insurance.csv")

# %% [markdown]
# ### Filtrando

# %%
df = df[['age', 'sex']]

# %% [markdown]
# ## Select

# %% [markdown]
# A instrução SELECT é usada para selecionar dados de um banco de dados.
#
# Os dados retornados são armazenados em uma tabela de resultados, chamada conjunto de resultados.

# %%
query = "SELECT age, sex FROM df LIMIT 6"
ps.sqldf(query,locals())
# Out:
#    age     sex
# 0   19  female
# 1   18    male
# 2   28    male
# 3   33    male
# 4   32    male
# 5   31  female

# %%
df_select_pandas = df[['age', 'sex']]
df_select_pandas.head(6)
# Out:
#    age     sex
# 0   19  female
# 1   18    male
# 2   28    male
# 3   33    male
# 4   32    male
# 5   31  female

# %% [markdown]
# ## Where

# %% [markdown]
# A cláusula WHERE é usada para filtrar registros.
#
# É usado para extrair apenas os registros que atendem a uma condição especificada.

# %%
query = "SELECT * FROM df WHERE age < 19 LIMIT 6"
ps.sqldf(query, locals())
# Out:
#    age     sex
# 0   18    male
# 1   18    male
# 2   18  female
# 3   18  female
# 4   18  female
# 5   18    male

# %%
df_where_age_pandas = df[(df['age'] < 19)]
df_where_age_pandas.head(6)
# Out:
#     age     sex
# 1    18    male
# 22   18    male
# 31   18  female
# 46   18  female
# 50   18  female
# 57   18    male

# %%
df_where_age_pandas = df[(df['age'] < 19)]

# %% [markdown]
# ## Order by

# %% [markdown]
# A palavra-chave ORDER BY é usada para classificar o conjunto de resultados em ordem crescente ou decrescente.
#
# A palavra-chave ORDER BY classifica os registros em ordem crescente por padrão. Para classificar os registros em ordem decrescente, use a palavra-chave DESC.

# %%
query = "SELECT * FROM df ORDER BY age DESC LIMIT 6"
ps.sqldf(query, locals())
# Out:
#    age     sex
# 0   64    male
# 1   64  female
# 2   64  female
# 3   64  female
# 4   64    male
# 5   64  female

# %%
df_orderby_pandas = df.sort_values(by='age', ascending=False)
df_orderby_pandas.head(6)
# Out:
#       age     sex
# 335    64    male
# 603    64  female
# 752    64    male
# 1265   64    male
# 534    64    male
# 328    64  female

# %% [markdown]
# ## Group by

# %% [markdown]
# A instrução GROUP BY agrupa linhas que possuem os mesmos valores em linhas de resumo, como "encontre o número de clientes em cada país".
#
# A instrução GROUP BY é frequentemente usada com funções agregadas (COUNT(), MAX(), MIN(), SUM(), AVG()) para agrupar o conjunto de resultados por uma ou mais colunas.

# %%
query = "SELECT AVG(age), sex FROM df GROUP BY sex"
ps.sqldf(query, locals())
# Out:
#     AVG(age)     sex
# 0  39.503021  female
# 1  38.917160    male

# %%
df_groupby_pandas = df.groupby('sex')['age'].mean()

# %%
df_groupby_pandas = df.groupby('sex')['age'].mean().reset_index()
df_groupby_pandas
# Out:
#       sex        age
# 0  female  39.503021
# 1    male  38.917160

# %% [markdown]
# ## Count

# %% [markdown]
# A função COUNT() retorna o número de linhas que corresponde a um critério especificado.

# %%
query = "SELECT COUNT(age) FROM df GROUP BY age LIMIT 6"
ps.sqldf(query, locals())
# Out:
#    COUNT(age)
# 0          69
# 1          68
# 2          29
# 3          28
# 4          28
# 5          28

# %%
df_count_pandas = df['age'].value_counts().reset_index()
df_count_pandas.head(6)
# Out:
#    index  age
# 0     18   69
# 1     19   68
# 2     50   29
# 3     51   29
# 4     47   29
# 5     46   29
